# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
pip install citipy
# Out:
# Collecting citipy
#   Using cached citipy-0.0.5.tar.gz (557 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting kdtree>=0.12
#   Using cached kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Installing collected packages: kdtree, citipy
#   Running setup.py install for citipy: started
#   Running setup.py install for citipy: finished with status 'done'
# Successfully installed citipy-0.0.5 kdtree-0.16
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: citipy is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key
print(weather_api_key)

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Dependencies and Setup
# ----> 2 import matplotlib.pyplot as plt
#       3 import pandas as pd
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 617

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
base_url = url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kaeo
# Processing Record 2 of Set 1 | grindavik
# Processing Record 3 of Set 1 | ilulissat
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | normandin
# Processing Record 9 of Set 1 | lorengau
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | thompson
# Processing Record 13 of Set 1 | dikson
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | upernavik
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | ola
# Processing Record 19 of Set 1 | yerbogachen
# Processing Record 20 of Set 1 | batagay-alyta
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | luderitz
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | maltahohe
# Processing Record 25 of Set 1 | westport
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | lata
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | edd
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | auchterarder
# Processing Record 32 of Set 1 | trofors
# Processing Record 33 of Set 1 | te anau
# Processing Record 34 of Set 1 | kozhva
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | new norfolk
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | coahuayana
# Processing Record 41 of Set 1 | grand junction
# Processing Record 42 of Set 1 | mitsamiouli
# Processing Record 43 of Set 1 | heinsberg
# Processing Record 44 of Set 1 | sao joao da barra
# Processing Record 45 of Set 1 | etchojoa
# Processing Record 46 of Set 1 | smithers
# Processing Record 47 of Set 1 | iqaluit
# Processing Record 48 of Set 1 | tuktoyaktuk
# Processing Record 49 of Set 1 | skagastrond
# City not found. Skipping...
# Processing Record 50 of Set 1 | nemuro
# Processing Record 0 of Set 2 | gunjur
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | funtua
# Processing Record 3 of Set 2 | havre-saint-pierre
# Processing Record 4 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 2 | high level
# Processing Record 6 of Set 2 | esperance
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | porto novo
# Processing Record 10 of Set 2 | orel-izumrud
# Processing Record 11 of Set 2 | severo-kurilsk
# Processing Record 12 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 2 | tavda
# Processing Record 14 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | nikolskoye
# Processing Record 17 of Set 2 | majene
# Processing Record 18 of Set 2 | bay roberts
# Processing Record 19 of Set 2 | boshnyakovo
# Processing Record 20 of Set 2 | praia da vitoria
# Processing Record 21 of Set 2 | lebu
# Processing Record 22 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 2 | lagoa
# Processing Record 24 of Set 2 | sola
# Processing Record 25 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 2 | chokurdakh
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | oia
# Processing Record 29 of Set 2 | alenquer
# Processing Record 30 of Set 2 | qaanaaq
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | hofn
# Processing Record 33 of Set 2 | cascais
# Processing Record 34 of Set 2 | mataura
# Processing Record 35 of Set 2 | souillac
# Processing Record 36 of Set 2 | fort-shevchenko
# Processing Record 37 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 2 | ribeira grande
# Processing Record 39 of Set 2 | hobart
# Processing Record 40 of Set 2 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 41 of Set 2 | halifax
# Processing Record 42 of Set 2 | airai
# Processing Record 43 of Set 2 | husavik
# Processing Record 44 of Set 2 | vardo
# Processing Record 45 of Set 2 | severnyy
# Processing Record 46 of Set 2 | kieta
# Processing Record 47 of Set 2 | rawson
# Processing Record 48 of Set 2 | codrington
# Processing Record 49 of Set 2 | kruisfontein
# Processing Record 0 of Set 3 | san angelo
# Processing Record 1 of Set 3 | rio gallegos
# Processing Record 2 of Set 3 | coquimbo
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | geraldton
# Processing Record 5 of Set 3 | uwayl
# City not found. Skipping...
# Processing Record 6 of Set 3 | port hedland
# Processing Record 7 of Set 3 | kanashevo
# Processing Record 8 of Set 3 | waddan
# Processing Record 9 of Set 3 | cape town
# Processing Record 10 of Set 3 | sapa
# Processing Record 11 of Set 3 | torbay
# Processing Record 12 of Set 3 | saldanha
# Processing Record 13 of Set 3 | georgetown
# Processing Record 14 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 15 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 3 | okhotsk
# Processing Record 18 of Set 3 | mar del plata
# Processing Record 19 of Set 3 | east london
# Processing Record 20 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 3 | portland
# Processing Record 22 of Set 3 | cherskiy
# Processing Record 23 of Set 3 | obo
# Processing Record 24 of Set 3 | vila franca do campo
# Processing Record 25 of Set 3 | faanui
# Processing Record 26 of Set 3 | cabo san lucas
# Processing Record 27 of Set 3 | westerland
# Processing Record 28 of Set 3 | hovd
# Processing Record 29 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 31 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 3 | altamont
# Processing Record 33 of Set 3 | saskylakh
# Processing Record 34 of Set 3 | plouzane
# Processing Record 35 of Set 3 | ostrovnoy
# Processing Record 36 of Set 3 | chuy
# Processing Record 37 of Set 3 | plettenberg bay
# Processing Record 38 of Set 3 | shubarkuduk
# Processing Record 39 of Set 3 | kavaratti
# Processing Record 40 of Set 3 | aksarka
# Processing Record 41 of Set 3 | saint-pierre
# Processing Record 42 of Set 3 | sitka
# Processing Record 43 of Set 3 | takoradi
# Processing Record 44 of Set 3 | tadine
# Processing Record 45 of Set 3 | acarau
# Processing Record 46 of Set 3 | lavrentiya
# Processing Record 47 of Set 3 | le vauclin
# Processing Record 48 of Set 3 | cap malheureux
# Processing Record 49 of Set 3 | igarka
# Processing Record 0 of Set 4 | los llanos de aridane
# Processing Record 1 of Set 4 | pevek
# Processing Record 2 of Set 4 | comodoro rivadavia
# Processing Record 3 of Set 4 | sitia
# Processing Record 4 of Set 4 | bousso
# Processing Record 5 of Set 4 | berga
# Processing Record 6 of Set 4 | provideniya
# Processing Record 7 of Set 4 | marinette
# Processing Record 8 of Set 4 | kaitangata
# Processing Record 9 of Set 4 | qunduz
# Processing Record 10 of Set 4 | south venice
# Processing Record 11 of Set 4 | sambava
# Processing Record 12 of Set 4 | wilmington island
# Processing Record 13 of Set 4 | sao filipe
# Processing Record 14 of Set 4 | constitucion
# Processing Record 15 of Set 4 | flinders
# Processing Record 16 of Set 4 | kars
# Processing Record 17 of Set 4 | puerto madero
# Processing Record 18 of Set 4 | chinsali
# Processing Record 19 of Set 4 | kapaa
# Processing Record 20 of Set 4 | ponta delgada
# Processing Record 21 of Set 4 | ransang
# Processing Record 22 of Set 4 | olinda
# Processing Record 23 of Set 4 | awbari
# Processing Record 24 of Set 4 | san miguel
# Processing Record 25 of Set 4 | qaqortoq
# Processing Record 26 of Set 4 | cordoba
# Processing Record 27 of Set 4 | goiatuba
# Processing Record 28 of Set 4 | muncie
# Processing Record 29 of Set 4 | boguchany
# Processing Record 30 of Set 4 | truth or consequences
# Processing Record 31 of Set 4 | serov
# Processing Record 32 of Set 4 | henties bay
# Processing Record 33 of Set 4 | aleksandrov gay
# Processing Record 34 of Set 4 | tambura
# Processing Record 35 of Set 4 | puerto baquerizo moreno
# Processing Record 36 of Set 4 | berdigestyakh
# Processing Record 37 of Set 4 | hayvoron
# Processing Record 38 of Set 4 | vista hermosa
# Processing Record 39 of Set 4 | nhulunbuy
# Processing Record 40 of Set 4 | yuzhno-kurilsk
# Processing Record 41 of Set 4 | santiago de cuba
# Processing Record 42 of Set 4 | inuvik
# Processing Record 43 of Set 4 | port hardy
# Processing Record 44 of Set 4 | whitianga
# Processing Record 45 of Set 4 | ust-nera
# Processing Record 46 of Set 4 | mahebourg
# Processing Record 47 of Set 4 | vargem alta
# Processing Record 48 of Set 4 | lodja
# Processing Record 49 of Set 4 | tokur
# Processing Record 0 of Set 5 | leningradskiy
# Processing Record 1 of Set 5 | robertsport
# Processing Record 2 of Set 5 | ahuimanu
# Processing Record 3 of Set 5 | varberg
# Processing Record 4 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 5 | seydi
# Processing Record 7 of Set 5 | tiksi
# Processing Record 8 of Set 5 | poyarkovo
# Processing Record 9 of Set 5 | ayorou

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          582
# Lat           582
# Lng           582
# Max Temp      582
# Humidity      582
# Cloudiness    582
# Wind Speed    582
# Country       582
# Date          582
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        eirunepe  -6.6603  -69.8736     23.04        93          42
# 1      nikolskoye  59.7035   30.7861     -1.06        88          99
# 2  saint-philippe -21.3585   55.7679     24.77        83          85
# 3        hermanus -34.4187   19.2345     19.89        81          42
# 4        shaoguan  24.8000  113.5833     14.59        92         100
#
#    Wind Speed Country        Date
# 0        0.82      BR  1675816129
# 1        4.46      RU  1675816129
# 2        6.27      RE  1675816109
# 3        5.38      ZA  1675816074
# 4        0.72      CN  1675816130

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              eirunepe  -6.6603  -69.8736     23.04        93          42
# 1            nikolskoye  59.7035   30.7861     -1.06        88          99
# 2        saint-philippe -21.3585   55.7679     24.77        83          85
# 3              hermanus -34.4187   19.2345     19.89        81          42
# 4              shaoguan  24.8000  113.5833     14.59        92         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.82      BR  1675816129
# 1              4.46      RU  1675816129
# 2              6.27      RE  1675816109
# 3              5.38      ZA  1675816074
# 4              0.72      CN  1675816130

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
Lat = city_data_df['Lat']
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Build scatter plot for latitude vs. temperature

plt.scatter(Lat, max_temps, marker="o", facecolors="blue", edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.xlabel("Lat")
plt.ylabel("Max Temp")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(Lat, humidity, marker="o", facecolors="blue", edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(Lat, cloudiness, marker="o", facecolors="blue", edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness "+ time.strftime("%x"))
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10356\2633286658.py in <module>
#       8 plt.grid(True)
#       9 # Save the figure
# ---> 10 plt.savefig("output_data/Fig3.png")
#      11
#      12 # Show plot
#
# c:\Users\G_Breezy\anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# c:\Users\G_Breezy\anaconda3\envs\PythonData\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# c:\Users\G_Breezy\anaconda3\envs\PythonData\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2124                     orientation=orientation,
#    2125                     bbox_inches_restore=_bbox_inches_restore,
# -> 2126                     **kwargs)
#    2127             finally:
#    2128                 if bbox_inches and restore_bbox:
#
# c:\Users\G_Breezy\anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# c:\Users\G_Breezy\anaconda3\envs\PythonData\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# c:\Users\G_Breezy\anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# c:\Users\G_Breezy\anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_data/Fig3.png'

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(Lat, wind_speed, marker="o", facecolors="blue", edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
        # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                ohara  35.2500  140.3833     10.44        74          98
# 1        makakilo city  21.3469 -158.0858     28.18        69          75
# 3               kodiak  57.7900 -152.4072     -1.27        51           0
# 4          yellowknife  62.4560 -114.3525    -18.58        78          75
# 12             alamosa  37.4695 -105.8700      3.99        17           0
#
#          Wind Speed Country        Date
# City_ID
# 0              7.95      JP  1675813201
# 1              6.69      US  1675813203
# 3              6.69      US  1675813208
# 4              3.09      CA  1675813209
# 12             3.09      US  1675813215

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        constitucion -35.3333  -72.4167     15.89        74           8
# 5           busselton -33.6500  115.3333     20.08        68          26
# 6             ushuaia -54.8000  -68.3000     12.81        44           0
# 7            hokitika -42.7167  170.9667     16.09        66          81
# 8            necochea -38.5473  -58.7368     22.69        78          38
#
#          Wind Speed Country        Date
# City_ID
# 2              4.38      CL  1675813206
# 5              4.50      AU  1675813210
# 6              1.54      AR  1675813130
# 7              6.23      NZ  1675813211
# 8              7.71      AR  1675813212

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

plot_linear_regression(x_values, y_values,"Linear Regression on the Northern Hemisphere \n for Maximum Temperature", 'Max Temp',(30,30))

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

plot_linear_regression(x_values, y_values,
                       "Linear Regression on the Southern Hemisphere \n for Maximum Temperature", 'Max Temp',(-10,20))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

plot_linear_regression(x_values, y_values,
                       "Linear Regression on the Northern Hemisphere \n for % Humidity", '% Humidity',(45,5))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

plot_linear_regression(x_values, y_values,
                       "Linear Regression on the Southern Hemisphere \n for % Humidity", '% Humidity',(-55,15))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(10,60))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-10,40))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(20,25))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4532\2460416334.py in <module>
#       1 # Northern Hemisphere
# ----> 2 x_values = northern_hemi_df["Lat"]
#       3 y_values = northern_hemi_df["Wind Speed"]
#       4
#       5 plot_linear_regression(x_values, y_values,
#
# NameError: name 'northern_hemi_df' is not defined

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed',(-10,25))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
